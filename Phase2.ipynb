# %% [markdown]
# ## *Phase 2 - Sublister, amass, knock.py, subbrute*

# %%
import os
from Subdigger import *

# %%
ins = Subdigger("https://rishabh.com")
# Out:
# The domain you entered is [ https://rishabh.com ].

# %%
print(type(Subdigger))
# Out:
# <class 'type'>
